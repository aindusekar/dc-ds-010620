# %% [markdown]
# # Statistical Power
#
# ## What is Statistical Power?
#
# The probability that it will reject a false null-hypothesis.
#
# > Power is the likelihood that a study will detect an effect when there is an effect there to be detected.
#
#
# Recall that we defined $\beta$ as the probability of making a type-II error.
#
# Therefore: power = 1- $\beta$
#
#
# > If the effect is bigger than more easier to detect the effect --> more power.
#
# > If the sample size is large than the tests are usually more sensitive to the effect --> more power.

# %% [markdown]
# [How do you calculate power?](https://effectsizefaq.com/2010/05/31/how-do-i-calculate-statistical-power/)

# %%
from statsmodels.stats.power import TTestIndPower

# %%
analysis = TTestIndPower()

# parameters for power analysis
effect = 0.8
alpha = 0.05
nobs1 = 50
power = .2
# perform power analysis
analysis = TTestIndPower()
result = analysis.solve_power(effect, power=power, nobs1=None, ratio=2.0, alpha=alpha)
print('Sample Size: %.3f' % result)
# Out:
# Sample Size: 3.636

# %%
from numpy import array
from matplotlib import pyplot
# %matplotlib inline
from statsmodels.stats.power import TTestIndPower
# parameters for power analysis
effect_sizes = array([0.2, 0.5, 0.8])
sample_sizes = array(range(5, 100))
# calculate power curves from multiple power analyses
analysis = TTestIndPower()
analysis.plot_power(dep_var='nobs', nobs=sample_sizes, effect_size=effect_sizes)
pyplot.show()

# %%
from numpy import array
from matplotlib import pyplot
# %matplotlib inline
from statsmodels.stats.power import TTestIndPower
# parameters for power analysis
sample_sizes = array(range(5, 100))
alpha_values = array([.01, .05, .1])
# calculate power curves from multiple power analyses
analysis = TTestIndPower()
analysis.plot_power(dep_var='alpha', nobs=sample_sizes, effect_size= .5, alpha = alpha_values)
pyplot.show()

# %%
from numpy import array
from matplotlib import pyplot
# %matplotlib inline
from statsmodels.stats.power import TTestIndPower
# parameters for power analysis
effect_sizes = array([0.2, 0.5, 0.8])
sample_sizes = array(range(5, 100))
# calculate power curves from multiple power analyses
analysis = TTestIndPower()
analysis.plot_power(dep_var='nobs', nobs=sample_sizes, effect_size=effect_sizes, alpha =)
pyplot.show()

# %% [markdown]
# __Your Turn__
#
# - Plot the power curves of different standard significance levels against the sample size.

# %% [markdown]
# # Extras
#
# [What is an ideal level of statistical power](https://effectsizefaq.com/2010/05/31/what-is-an-ideal-level-of-statistical-power/)

# %% [markdown]
# # Resources
#
# [Effectsizefaq](https://effectsizefaq.com/category/statistical-power/)
#
# [MachineLearningMastery](https://machinelearningmastery.com/statistical-power-and-power-analysis-in-python/)
#
# [Statsmodels - Power and sample size calculations](https://www.statsmodels.org/dev/stats.html#power-and-sample-size-calculations)
